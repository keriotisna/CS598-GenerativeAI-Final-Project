# %%
import numpy as np
import os

import matplotlib.pyplot as plt

# %%
dataPath = os.path.normpath(r'Data\FONTS\character_font.npz')

loadedData = np.load(dataPath)

images = loadedData['images']
labels = loadedData['labels']


for i in range(2*26):
    plt.imshow(images[i]), plt.title(labels[i]), plt.show()
# Out:
# NpzFile 'Data\\FONTS\\archive(1)\\character_font.npz' with keys: images, labels
